# %%
# Unzip uploaded hardware folder
# !unzip hardware.zip -d .
# Out:
# Archive:  hardware.zip
#    creating: ./hardware/
#   inflating: ./hardware/alert_dispatch.py
#   inflating: ./hardware/bilstm.py
#    creating: ./hardware/data/
#   inflating: ./hardware/data/filter_comparison.png
#   inflating: ./hardware/data/hw_csi.npy
#   inflating: ./hardware/data/hw_features.npy
#   inflating: ./hardware/data/hw_X.npy
#   inflating: ./hardware/data/hw_y.npy
#   inflating: ./hardware/data/labeled crash non crash sensor_data_2026-08-21_11-11-36.csv
#   inflating: ./hardware/data/sensor_data_2026-08-21_11-36-48.csv
#   inflating: ./hardware/data_pipeline.py
#   inflating: ./hardware/edge_inference.py
#   inflating: ./hardware/feature_engineering.py
#    creating: ./hardware/models/
#   inflating: ./hardware/train_phase2.py
#    creating: ./hardware/__pycache__/
#   inflating: ./hardware/__pycache__/bilstm.cpython-314.pyc
#   inflating: ./hardware/__pycache__/feature_engineering.cpython-314.pyc
#   inflating: ./hardware/__pycache__/train_phase2.cpython-314.pyc

# %%
# Install requirements
# !pip install torch torchvision optuna xgboost scikit-learn onnx onnxruntime tqdm scipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 63.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 14.2 MB/s eta 0:00:00
# ...

# %%
# !pip install onnxscript onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.0/722.0 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 20.3 MB/s eta 0:00:00
# ...

# %%
# Run training
# !python hardware/train_phase2.py
# Out:
# ...
#   IntelliCrash Hardware — Phase 2 Model Training
#   Binary Crash Detection: Bi-LSTM + XGBoost + CSI Fusion
# ...
# [Seed] All random seeds set to 42 for reproducibility.
#   Device: cuda
#   GPU: Tesla T4
#
# ...
#   SECTION 1: LOADING PREPROCESSED DATA
# ...
#   X (raw windows):  (1528, 200, 6)
#   y (labels):       (1528,)
#   features (26):    (1528, 26)
#   CSI scores:       (1528,)
#   CRASH:     820 (53.7%)
#   NON_CRASH: 708 (46.3%)
#
# ...
#   SECTION 2: TRAIN / VAL / TEST SPLIT
# ...
#
#   Split       Total    CRASH  NON_CRASH   Crash%
#   --------------------------------------------
#   train       1,069      617        452    57.7%
#   val           229      108        121    47.2%
#   test          230       95        135    41.3%
#   TOTAL       1,528
#
#   Seed: 42 | Ratio: 0.7/0.15/0.15
#
# ...
#   SECTION 4A: INITIAL BI-LSTM TRAINING (Default HParams)
# ...
# [Seed] All random seeds set to 42 for reproducibility.
#
#   Training Bi-LSTM [default-hparams]...
#   Hyperparameters: {
#   "hidden_size": 128,
# ...

# %%
from google.colab import files
# !zip -r hardware_trained_models.zip hardware/models/
files.download('hardware_trained_models.zip')
# Out:
#   adding: hardware/models/ (stored 0%)
#   adding: hardware/models/hw_bilstm.onnx (deflated 88%)
#   adding: hardware/models/hw_xgboost.json (deflated 73%)
#   adding: hardware/models/training_results.json (deflated 65%)
#   adding: hardware/models/hw_bilstm.onnx.data (deflated 8%)
#   adding: hardware/models/hw_best_bilstm.pth (deflated 8%)
